# %%
import pandas as pd
import geopandas as gpd
import rasterio
import xarray as xr
import sklearn
import xgboost
import streamlit

print("all core libs are installed- yeppie!!!")
# Out:
# all core libs are installed- yeppie!!!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.title("vs code notebook test")
plt.show()
