# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Ibrahim\Personal\University Stuff\Machine Learning\Project\ML Irrigation Project\data\raw\final_district_dataset.csv")

# %%
df.head(10)
# Out:
#   District  Year  Avg_Rainfall  Area_Sown  Wheat_Percentage  Avg_Temperature  \
# 0    PK203  1981      3.423858        NaN               NaN        20.206408
# 1    PK203  1982      6.698594        NaN               NaN        19.510198
# 2    PK203  1983      3.331681        NaN               NaN        19.611718
# 3    PK203  1984      2.419928        NaN               NaN        19.920437
# 4    PK203  1985      2.637431        NaN               NaN        20.242908
# 5    PK203  1986      2.657394        NaN               NaN        19.578992
# 6    PK203  1987      2.810428        NaN               NaN        20.427150
# 7    PK203  1988      3.055322        NaN               NaN        20.858067
# 8    PK203  1989      3.025525        NaN               NaN        19.541077
# 9    PK203  1990      3.990772        NaN               NaN        20.353342
#
#    Crop_Yield  Irrigation_Area
# 0         NaN              NaN
# 1         NaN              NaN
# 2         NaN              NaN
# 3         NaN              NaN
# 4         NaN              NaN
# 5         NaN              NaN
# 6         NaN              NaN
# 7         NaN              NaN
# 8         NaN              NaN
# 9         NaN              NaN

# %%
df.tail(10)
# Out:
#        District  Year  Avg_Rainfall  Area_Sown  Wheat_Percentage  \
# 300680    PK726  2020     12.421911        NaN               NaN
# 300681    PK726  2020     12.421911        NaN               NaN
# 300682    PK726  2020     12.421911        NaN               NaN
# 300683    PK726  2020     12.421911        NaN               NaN
# 300684    PK726  2020     12.421911        NaN               NaN
# 300685    PK726  2020     12.421911        NaN               NaN
# 300686    PK726  2021      8.111194        NaN               NaN
# 300687    PK726  2022     13.480117        NaN               NaN
# 300688    PK726  2023      8.965433        NaN               NaN
# 300689    PK726  2024      7.396167        NaN               NaN
#
#         Avg_Temperature  Crop_Yield  Irrigation_Area
# 300680              NaN      2598.0             53.0
# 300681              NaN      3682.0            119.0
# 300682              NaN      3971.0            129.0
# 300683              NaN      3306.0            103.0
# 300684              NaN      3186.0            137.0
# 300685              NaN      3036.0            153.0
# 300686              NaN         NaN              NaN
# 300687              NaN         NaN              NaN
# 300688              NaN         NaN              NaN
# 300689              NaN         NaN              NaN

# %%
df.shape
# Out:
# (300690, 8)

# %%
#remove duplicate district-year rows
dup = df.groupby(["District", "Year"]).size().sort_values(ascending=False)

dup.head(20)
# Out:
# District  Year
# PK718     2009    512
# PK203     2009    512
# PK714     2009    512
# PK629     2009    512
# PK614     2009    512
# PK626     2009    512
# PK709     2009    512
# PK708     2009    512
# PK636     2009    512
# PK711     2009    512
# PK204     2009    512
# PK530     2009    512
# PK211     2009    512
# PK603     2009    512
# PK604     2009    512
# PK209     2009    512
# PK609     2009    512
# PK612     2009    512
# PK519     2009    512
# PK516     2009    512
# dtype: int64

# %%
df = df.groupby(["District", "Year"], as_index=False).agg({
    "Avg_Rainfall":"mean",
    "Area_Sown":"mean",
    "Wheat_Percentage":"mean",
    "Avg_Temperature":"mean",
    "Crop_Yield":"mean",
    "Irrigation_Area":"mean"
})

# %%
df.head(15)
# Out:
#    District  Year  Avg_Rainfall  Area_Sown  Wheat_Percentage  Avg_Temperature  \
# 0     PK203  1981      3.423858        NaN               NaN        20.206408
# 1     PK203  1982      6.698594        NaN               NaN        19.510198
# 2     PK203  1983      3.331681        NaN               NaN        19.611718
# 3     PK203  1984      2.419928        NaN               NaN        19.920437
# 4     PK203  1985      2.637431        NaN               NaN        20.242908
# 5     PK203  1986      2.657394        NaN               NaN        19.578992
# 6     PK203  1987      2.810428        NaN               NaN        20.427150
# 7     PK203  1988      3.055322        NaN               NaN        20.858067
# 8     PK203  1989      3.025525        NaN               NaN        19.541077
# 9     PK203  1990      3.990772        NaN               NaN        20.353342
# 10    PK203  1991      3.493017        NaN               NaN        19.842869
# 11    PK203  1992      3.450828        NaN               NaN        19.705822
# 12    PK203  1993      2.821083        NaN               NaN        20.407645
# 13    PK203  1994      2.758992        NaN               NaN        20.111693
# 14    PK203  1995      3.122522        NaN               NaN        19.943789
#
#     Crop_Yield  Irrigation_Area
# 0          NaN              NaN
# 1          NaN              NaN
# 2          NaN              NaN
# 3          NaN              NaN
# 4          NaN              NaN
# 5          NaN              NaN
# 6          NaN              NaN
# 7          NaN              NaN
# 8          NaN              NaN
# 9          NaN              NaN
# 10         NaN              NaN
# 11         NaN              NaN
# 12         NaN              NaN
# 13         NaN              NaN
# 14         NaN              NaN

# %%
df.shape
# Out:
# (1320, 8)

# %%
#cleaning numeric cols
num_cols = ["Avg_Rainfall","Area_Sown","Wheat_Percentage","Avg_Temperature",
            "Crop_Yield","Irrigation_Area"]

for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
#handling missing vals

df.isna().sum()
# Out:
# District               0
# Year                   0
# Avg_Rainfall           0
# Area_Sown           1320
# Wheat_Percentage    1320
# Avg_Temperature      240
# Crop_Yield           690
# Irrigation_Area      690
# dtype: int64

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

df.isna().sum()
# Out:
# District               0
# Year                   0
# Avg_Rainfall           0
# Area_Sown           1320
# Wheat_Percentage    1320
# Avg_Temperature        0
# Crop_Yield             0
# Irrigation_Area        0
# dtype: int64

# %%
df.shape
# Out:
# (1320, 8)

# %%
df.head()
# Out:
#   District  Year  Avg_Rainfall  Area_Sown  Wheat_Percentage  Avg_Temperature  \
# 0    PK203  1981      3.423858        NaN               NaN        20.206408
# 1    PK203  1982      6.698594        NaN               NaN        19.510198
# 2    PK203  1983      3.331681        NaN               NaN        19.611718
# 3    PK203  1984      2.419928        NaN               NaN        19.920437
# 4    PK203  1985      2.637431        NaN               NaN        20.242908
#
#     Crop_Yield  Irrigation_Area
# 0  2973.113131       118.704918
# 1  2973.113131       118.704918
# 2  2973.113131       118.704918
# 3  2973.113131       118.704918
# 4  2973.113131       118.704918

# %%
df.tail(10)
# Out:
#      District  Year  Avg_Rainfall  Area_Sown  Wheat_Percentage  \
# 1310    PK726  2015      8.453675        NaN               NaN
# 1311    PK726  2016      6.903961        NaN               NaN
# 1312    PK726  2017      9.817506        NaN               NaN
# 1313    PK726  2018      3.318286        NaN               NaN
# 1314    PK726  2019     10.485631        NaN               NaN
# 1315    PK726  2020     12.421911        NaN               NaN
# 1316    PK726  2021      8.111194        NaN               NaN
# 1317    PK726  2022     13.480117        NaN               NaN
# 1318    PK726  2023      8.965433        NaN               NaN
# 1319    PK726  2024      7.396167        NaN               NaN
#
#       Avg_Temperature   Crop_Yield  Irrigation_Area
# 1310        20.559059  3006.106610       119.558635
# 1311        21.414617  2985.375839       120.281879
# 1312        20.417397  2969.108481       118.157791
# 1313        20.417397  2958.949495       119.383838
# 1314        20.417397  2959.044304       117.308017
# 1315        20.417397  2975.688525       118.704918
# 1316        20.417397  2973.113131       118.704918
# 1317        20.417397  2973.113131       118.704918
# 1318        20.417397  2973.113131       118.704918
# 1319        20.417397  2973.113131       118.704918

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns={"Area_Sown", "Wheat_Percentage"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = df.drop(columns={"Area_Sown", "Wheat_Percentage"})
#
# File c:\Ibrahim\Personal\University Stuff\Machine Learning\Project\ML Irrigation Project\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Ibrahim\Personal\University Stuff\Machine Learning\Project\ML Irrigation Project\venv\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Ibrahim\Personal\University Stuff\Machine Learning\Project\ML Irrigation Project\venv\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Ibrahim\Personal\University Stuff\Machine Learning\Project\ML Irrigation Project\venv\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Area_Sown', 'Wheat_Percentage'] not found in axis"

# %%
df.columns.tolist()
# Out:
# ['District',
#  'Year',
#  'Avg_Rainfall',
#  'Avg_Temperature',
#  'Crop_Yield',
#  'Irrigation_Area']

# %%
df.shape
# Out:
# (1320, 6)
